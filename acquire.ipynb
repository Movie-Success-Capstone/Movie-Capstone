# %% [markdown]
# # Aquisition
# [Overall Data Source with Dataset Details](https://www.imdb.com/interfaces/)
# [Data Location](https://datasets.imdbws.com)
#
# The Internet Movie Database (IMDb) freely provides subset of its data for personal and non-commercial uses. Any instance of web-scraping is strictly prohibited, so although there may have been a means of obtaining data that way, we opted to abide by IMDb's site access policies. That said, all content included herein as far as the data set itself is the property of IMDb. This presentation is purely for educational purposes and is not meant to expressly critique the aggregate data. All that said, lets obtain the data sets.
#
# There are seven separate sub datasets that are contained in a gzipped, tab-separated-values (TSV) formatted file in the UTF-8 character set. A '/N' is used to denote that a particular field is missing or null for that title/name.
#
# Each of the seven datasets are successfully merged along the primary key 'tconst' for each of the respective title subsets and the primary key from name.basics.tsv as 'nconst', which was merged with the foreign key 'nconst' in title.principals, which contains the meta data for the cast/crew per title.
#
# At the end of acquisition, the combined dataframe was saved to .csv and subsequently read in as the dataframe for preparation and pre-processing.
# ***

# %%
import pandas as pd

# %%
df = pd.read_csv('data-2.tsv', sep ='\t')

# %%
df
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 8946053  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8946054  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8946055  tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8946056  tt9916856           nm10538645                      nm6951431
# 8946057  tt9916880            nm0996406            nm1482639,nm2586970
#
# [8946058 rows x 3 columns]

# %%
df1 = pd.read_csv('data-3.tsv', sep ='\t')
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.to_csv('title_basics_unfiltered.csv', index=False)

# %%
import mitosheet
mitosheet.sheet(df1, analysis_to_replay="id-hamtlyclfd")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-hamtlyclfd", "analysisToReplay": null, "code": [], "stepSu…

# %%
from mitosheet import *; # Analysis Name:id-hamtlyclfd;
    
# Filtered titleType
df1 = df1[df1['titleType'].apply(lambda val: all(val != s for s in ['short', 'tvEpisode', 'tvMiniSeries', 'tvPilot', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame']))]

# Filtered startYear
df1 = df1[df1['startYear'].apply(lambda val: all(val != s for s in ['1999', '1998', '1997', '1995', '1994', '1992', '1991', '1987', '1985', '1984', '1982', '1904', '1903', '1902', '1901', '1900', '1899', '1898', '1897', '1896']))]

# %%
df1 = df1[df1['titleType'] == 'movie']

# %%
df1

# %%
import mitosheet
mitosheet.sheet(df1, analysis_to_replay="id-hhnrsklphg")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-hhnrsklphg", "analysisToReplay": null, "code": [], "stepSu…

# %%
from mitosheet import *; # Analysis Name:id-hhnrsklphg;
    
# Filtered startYear
df1 = df1[df1['startYear'] != '\N']

# %%
df1.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
df1.startYear.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qn/sd1_3x2j4196db03067vql600000gn/T/ipykernel_5172/2145101855.py in <module>
# ----> 1 df1.startYear.astype(int)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '\\N'

# %%
df1.startYear.unique() # //N is messing shit up
# Out:
# array([1905, 1906, 1907, 1908, 1909, 1910, 1912, 1911, 1913, 1915, 1914,
#        1919, 1916, 1917, 1936, 1925, 1918, 1920, 1922, 1921, 1924, 1923,
#        1928, 2019, 2021, 1926, 1927, 1929, 2000, 1993, 1935, 1930, 1942,
#        1932, 1931, 1934, 1939, 1937, 1933, 1950, 1938, 1951, 1946, 1996,
#        1940, 1944, 1947, 1941, 1952, 1970, 1957, 1943, 1948, 1945, 2001,
#        1949, 1953, 1954, 1965, 1983, 1980, 1973, 1961, 1955, 1962, 1958,
#        1956, 1977, 1964, 1960, 1959, 1967, 1968, 1963, 1971, 1969, 1972,
#        1966, 1976, 1990, 1979, 1981, 2020, 1975, 1978, 1989, 1974, 1986,
#        '1972', '1971', '1970', '1974', '1973', '1976', '1969', '1981',
#        '1968', '1995', '1986', '1987', '1975', '1965', '1978', '1967',
#        '1990', '1980', '1985', '2018', '1977', '1989', '1979', '1984',
#        '1966', '1982', '1988', '1983', '1991', '1963', '2001', '1961',
#        '\\N', '1994', '1993', '1964', '1957', '2019', '1992', '2005',
#        '1953', '2004', '1998', '2020', '1947', '2016', '2002', '1996',
#        '2017', '1997', '2000', '1945', '1956', '2021', '1999', '2006',
#        '1955', '1949', '2008', '2009', '2003', '2007', '2022', '1930',
#        '1938', '1959', '1960', '1944', '1935', '1962', '1951', '1954',
#        '1952', '1958', '1918', '1943', '1921', '1941', '1939', '1940',
#        '1950', '1946', '1916', '1934', '1948', '1933', '1929', '1936',
#        '1925', '1932', '1928', '1917', '1919', '1926', '1937', '1931',
#        '1920', '1942', '1922', '1927', '1923', '1924', '1915', '1914',
#        '1913', '1911', '2010', '1912', '1909', '1910', '1905', '1898',
#        '1899', '2012', '1908', '2013', '1906', '1907', '2011', '1904',
#        '2024', '2015', '1897', '1901', '1902', '1900', '1903', '2014',
#        '2023', '2025', '2027', '2026', '2028', '2029', '1896'],
#       dtype=object)

# %%
df1 = df1[df1['startYear'] != '\\N']

# %%
df1.startYear.unique()
# Out:
# array([1905, 1906, 1907, 1908, 1909, 1910, 1912, 1911, 1913, 1915, 1914,
#        1919, 1916, 1917, 1936, 1925, 1918, 1920, 1922, 1921, 1924, 1923,
#        1928, 2019, 2021, 1926, 1927, 1929, 2000, 1993, 1935, 1930, 1942,
#        1932, 1931, 1934, 1939, 1937, 1933, 1950, 1938, 1951, 1946, 1996,
#        1940, 1944, 1947, 1941, 1952, 1970, 1957, 1943, 1948, 1945, 2001,
#        1949, 1953, 1954, 1965, 1983, 1980, 1973, 1961, 1955, 1962, 1958,
#        1956, 1977, 1964, 1960, 1959, 1967, 1968, 1963, 1971, 1969, 1972,
#        1966, 1976, 1990, 1979, 1981, 2020, 1975, 1978, 1989, 1974, 1986,
#        '1972', '1971', '1970', '1974', '1973', '1976', '1969', '1981',
#        '1968', '1995', '1986', '1987', '1975', '1965', '1978', '1967',
#        '1990', '1980', '1985', '2018', '1977', '1989', '1979', '1984',
#        '1966', '1982', '1988', '1983', '1991', '1963', '2001', '1961',
#        '1994', '1993', '1964', '1957', '2019', '1992', '2005', '1953',
#        '2004', '1998', '2020', '1947', '2016', '2002', '1996', '2017',
#        '1997', '2000', '1945', '1956', '2021', '1999', '2006', '1955',
#        '1949', '2008', '2009', '2003', '2007', '2022', '1930', '1938',
#        '1959', '1960', '1944', '1935', '1962', '1951', '1954', '1952',
#        '1958', '1918', '1943', '1921', '1941', '1939', '1940', '1950',
#        '1946', '1916', '1934', '1948', '1933', '1929', '1936', '1925',
#        '1932', '1928', '1917', '1919', '1926', '1937', '1931', '1920',
#        '1942', '1922', '1927', '1923', '1924', '1915', '1914', '1913',
#        '1911', '2010', '1912', '1909', '1910', '1905', '1898', '1899',
#        '2012', '1908', '2013', '1906', '1907', '2011', '1904', '2024',
#        '2015', '1897', '1901', '1902', '1900', '1903', '2014', '2023',
#        '2025', '2027', '2026', '2028', '2029', '1896'], dtype=object)

# %%
df1.startYear.astype(int)
# Out:
# 498        1905
# 570        1906
# 587        1907
# 610        1907
# 625        1908
#            ...
# 8945948    2015
# 8945975    2007
# 8945987    2013
# 8945998    2017
# 8946008    2013
# Name: startYear, Length: 531264, dtype: int64

# %%
df1.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
df1['startYear'] = df1['startYear'].astype(int)
# Out:
# /var/folders/qn/sd1_3x2j4196db03067vql600000gn/T/ipykernel_5172/2264485275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['startYear'] = df1['startYear'].astype(int)

# %%
df1.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear          int64
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
df1 = df1[df1['startYear'] >= 2000]

# %%
df1.startYear.unique()
# Out:
# array([2019, 2021, 2000, 2001, 2020, 2018, 2005, 2004, 2016, 2002, 2017,
#        2006, 2008, 2009, 2003, 2007, 2022, 2010, 2012, 2013, 2011, 2024,
#        2015, 2014, 2023, 2025, 2027, 2026, 2028, 2029])

# %%
df1.shape
# Out:
# (280658, 9)

# %%
df1.to_csv('title_basics.csv', index=False)

# %%
df = pd.read_csv('title_basics.csv')

# %%
df
# Out:
#            tconst titleType  \
# 0       tt0011801     movie
# 1       tt0013274     movie
# 2       tt0015414     movie
# 3       tt0035423     movie
# 4       tt0062336     movie
# ...           ...       ...
# 280653  tt9916622     movie
# 280654  tt9916680     movie
# 280655  tt9916706     movie
# 280656  tt9916730     movie
# 280657  tt9916754     movie
#
#                                              primaryTitle  \
# 0                                        Tötet nicht mehr
# 1                             Istoriya grazhdanskoy voyny
# 2                                  La tierra de los toros
# 3                                          Kate & Leopold
# 4       The Tango of the Widower and Its Distorting Mi...
# ...                                                   ...
# 280653        Rodolpho Teóphilo - O Legado de um Pioneiro
# 280654  De la ilusión al desconcierto: cine colombiano...
# 280655                                    Dankyavar Danka
# 280656                                             6 Gunn
# 280657                     Chico Albuquerque - Revelações
#
#                                             originalTitle  isAdult  startYear  \
# 0                                        Tötet nicht mehr        0       2019
# 1                             Istoriya grazhdanskoy voyny        0       2021
# 2                                  La tierra de los toros        0       2000
# 3                                          Kate & Leopold        0       2001
# 4               El Tango del Viudo y Su Espejo Deformante        0       2020
# ...                                                   ...      ...        ...
# 280653        Rodolpho Teóphilo - O Legado de um Pioneiro        0       2015
# 280654  De la ilusión al desconcierto: cine colombiano...        0       2007
# 280655                                    Dankyavar Danka        0       2013
# 280656                                             6 Gunn        0       2017
# 280657                     Chico Albuquerque - Revelações        0       2013
#
#        endYear runtimeMinutes                  genres
# 0           \N             \N            Action,Crime
# 1           \N            133             Documentary
# 2           \N             60                      \N
# 3           \N            118  Comedy,Fantasy,Romance
# 4           \N             70                   Drama
# ...        ...            ...                     ...
# 280653      \N             57             Documentary
# 280654      \N            100             Documentary
# 280655      \N             \N                  Comedy
# 280656      \N            116                      \N
# 280657      \N             49             Documentary
#
# [280658 rows x 9 columns]

# %%
df1 = pd.read_csv('data-2.tsv', sep ='\t')

# %%
df1
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 8946053  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8946054  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8946055  tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8946056  tt9916856           nm10538645                      nm6951431
# 8946057  tt9916880            nm0996406            nm1482639,nm2586970
#
# [8946058 rows x 3 columns]

# %% [markdown]
# In this tutorial, you’ll learn how and when to combine your data in pandas with:
#
# - merge() for combining data on common columns or indices
# - .join() for combining data on a key column or an index
# - concat() for combining DataFrames across rows or columns

# %%
dft =

# %%
df.shape
# Out:
# (280658, 9)

# %%
df1.shape
# Out:
# (8946058, 3)

# %%
df2 = pd.merge(df, df1, on='tconst')

# %%
df2
# Out:
#            tconst titleType  \
# 0       tt0011801     movie
# 1       tt0013274     movie
# 2       tt0015414     movie
# 3       tt0035423     movie
# 4       tt0062336     movie
# ...           ...       ...
# 280653  tt9916622     movie
# 280654  tt9916680     movie
# 280655  tt9916706     movie
# 280656  tt9916730     movie
# 280657  tt9916754     movie
#
#                                              primaryTitle  \
# 0                                        Tötet nicht mehr
# 1                             Istoriya grazhdanskoy voyny
# 2                                  La tierra de los toros
# 3                                          Kate & Leopold
# 4       The Tango of the Widower and Its Distorting Mi...
# ...                                                   ...
# 280653        Rodolpho Teóphilo - O Legado de um Pioneiro
# 280654  De la ilusión al desconcierto: cine colombiano...
# 280655                                    Dankyavar Danka
# 280656                                             6 Gunn
# 280657                     Chico Albuquerque - Revelações
#
#                                             originalTitle  isAdult  startYear  \
# 0                                        Tötet nicht mehr        0       2019
# 1                             Istoriya grazhdanskoy voyny        0       2021
# 2                                  La tierra de los toros        0       2000
# 3                                          Kate & Leopold        0       2001
# 4               El Tango del Viudo y Su Espejo Deformante        0       2020
# ...                                                   ...      ...        ...
# 280653        Rodolpho Teóphilo - O Legado de um Pioneiro        0       2015
# 280654  De la ilusión al desconcierto: cine colombiano...        0       2007
# 280655                                    Dankyavar Danka        0       2013
# 280656                                             6 Gunn        0       2017
# 280657                     Chico Albuquerque - Revelações        0       2013
#
#        endYear runtimeMinutes                  genres            directors  \
# 0           \N             \N            Action,Crime            nm0681726
# 1           \N            133             Documentary  nm0412842,nm0895048
# 2           \N             60                      \N            nm0615736
# 3           \N            118  Comedy,Fantasy,Romance            nm0003506
# 4           \N             70                   Drama  nm0749914,nm0765384
# ...        ...            ...                     ...                  ...
# 280653      \N             57             Documentary  nm9272491,nm9272490
# 280654      \N            100             Documentary            nm0652213
# 280655      \N             \N                  Comedy            nm7764440
# 280656      \N            116                      \N           nm10538612
# 280657      \N             49             Documentary  nm8349149,nm9272490
#
#                      writers
# 0        nm0483944,nm0681726
# 1                         \N
# 2                         \N
# 3        nm0737216,nm0003506
# 4        nm0749914,nm1146177
# ...                      ...
# 280653   nm9272490,nm9272491
# 280654  nm0652213,nm10538576
# 280655             nm7933903
# 280656            nm10538612
# 280657   nm8349149,nm9272490
#
# [280658 rows x 11 columns]

# %%
df2.to_csv('title_basics_and_title_crew.csv', index=False)

# %%
df3 = pd.read_csv('data-4.tsv', sep ='\t')
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df3

# %%
df3.rename(columns={'titleId': 'tconst'}, inplace=True)

# %%
df4 = pd.merge(df2, df3, on='tconst')

# %%
df4.shape
# Out:
# (1213147, 18)

# %%
df4
# Out:
#             tconst titleType  \
# 0        tt0011801     movie
# 1        tt0011801     movie
# 2        tt0011801     movie
# 3        tt0013274     movie
# 4        tt0013274     movie
# ...            ...       ...
# 1213142  tt9916680     movie
# 1213143  tt9916706     movie
# 1213144  tt9916730     movie
# 1213145  tt9916754     movie
# 1213146  tt9916754     movie
#
#                                               primaryTitle  \
# 0                                         Tötet nicht mehr
# 1                                         Tötet nicht mehr
# 2                                         Tötet nicht mehr
# 3                              Istoriya grazhdanskoy voyny
# 4                              Istoriya grazhdanskoy voyny
# ...                                                    ...
# 1213142  De la ilusión al desconcierto: cine colombiano...
# 1213143                                    Dankyavar Danka
# 1213144                                             6 Gunn
# 1213145                     Chico Albuquerque - Revelações
# 1213146                     Chico Albuquerque - Revelações
#
#                                              originalTitle  isAdult  \
# 0                                         Tötet nicht mehr        0
# 1                                         Tötet nicht mehr        0
# 2                                         Tötet nicht mehr        0
# 3                              Istoriya grazhdanskoy voyny        0
# 4                              Istoriya grazhdanskoy voyny        0
# ...                                                    ...      ...
# 1213142  De la ilusión al desconcierto: cine colombiano...        0
# 1213143                                    Dankyavar Danka        0
# 1213144                                             6 Gunn        0
# 1213145                     Chico Albuquerque - Revelações        0
# 1213146                     Chico Albuquerque - Revelações        0
#
#          startYear endYear runtimeMinutes        genres            directors  \
# 0             2019      \N             \N  Action,Crime            nm0681726
# 1             2019      \N             \N  Action,Crime            nm0681726
# 2             2019      \N             \N  Action,Crime            nm0681726
# 3             2021      \N            133   Documentary  nm0412842,nm0895048
# 4             2021      \N            133   Documentary  nm0412842,nm0895048
# ...            ...     ...            ...           ...                  ...
# 1213142       2007      \N            100   Documentary            nm0652213
# 1213143       2013      \N             \N        Comedy            nm7764440
# 1213144       2017      \N            116            \N           nm10538612
# 1213145       2013      \N             49   Documentary  nm8349149,nm9272490
# 1213146       2013      \N             49   Documentary  nm8349149,nm9272490
#
#                       writers  ordering  \
# 0         nm0483944,nm0681726         1
# 1         nm0483944,nm0681726         2
# 2         nm0483944,nm0681726         3
# 3                          \N         1
# 4                          \N         2
# ...                       ...       ...
# 1213142  nm0652213,nm10538576         2
# 1213143             nm7933903         1
# 1213144            nm10538612         1
# 1213145   nm8349149,nm9272490         1
# 1213146   nm8349149,nm9272490         2
#
#                                                      title region language  \
# 0                                         Tötet nicht mehr     DE       \N
# 1                         Misericordia - Tötet nicht mehr!     DE       \N
# 2                                         Tötet nicht mehr     \N       \N
# 3                                 History of the Civil War     \N       \N
# 4                             Histoire de la guerre civile     FR       \N
# ...                                                    ...    ...      ...
# 1213142  De la ilusión al desconcierto: cine colombiano...     \N       \N
# 1213143                                    Dankyavar Danka     IN       \N
# 1213144                                             6 Gunn     IN       \N
# 1213145                     Chico Albuquerque - Revelações     BR       \N
# 1213146                     Chico Albuquerque - Revelações     \N       \N
#
#                types        attributes isOriginalTitle
# 0        imdbDisplay                \N               0
# 1                 \N  censored version               0
# 2           original                \N               1
# 3                 \N                \N               0
# 4                 \N                \N               0
# ...              ...               ...             ...
# 1213142     original                \N               1
# 1213143           \N                \N               0
# 1213144           \N                \N               0
# 1213145  imdbDisplay                \N               0
# 1213146     original                \N               1
#
# [1213147 rows x 18 columns]

# %%
df5 = df4[df4['region'] == 'US']

# %%
df5.shape
# Out:
# (148940, 18)

# %%
df5.titleType.unique()
df5.startYear.unique()
df5.region.unique()
# Out:
# array(['US'], dtype=object)

# %%
df5.to_csv('title_basics_and_title_crew_title_akas.csv', index=False)

# %%
df6 = pd.read_csv('ratings.tsv', sep ='\t')

# %%
df6
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1882
# 1        tt0000002            5.9       250
# 2        tt0000003            6.5      1661
# 3        tt0000004            5.8       163
# 4        tt0000005            6.2      2486
# ...            ...            ...       ...
# 1247228  tt9916690            6.5         6
# 1247229  tt9916720            5.2       216
# 1247230  tt9916730            8.4         6
# 1247231  tt9916766            6.7        19
# 1247232  tt9916778            7.2        35
#
# [1247233 rows x 3 columns]

# %%
df7 = pd.merge(df5, df6, on='tconst')

# %%
df7
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0035423     movie
# 2       tt0062336     movie
# 3       tt0069049     movie
# 4       tt0088751     movie
# ...           ...       ...
# 101462  tt9915872     movie
# 101463  tt9916170     movie
# 101464  tt9916190     movie
# 101465  tt9916362     movie
# 101466  tt9916428     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1                                          Kate & Leopold
# 2       The Tango of the Widower and Its Distorting Mi...
# 3                              The Other Side of the Wind
# 4                                       The Naked Monster
# ...                                                   ...
# 101462                               The Last White Witch
# 101463                                      The Rehearsal
# 101464                                          Safeguard
# 101465                                              Coven
# 101466                                The Secret of China
#
#                                     originalTitle  isAdult  startYear endYear  \
# 0                                  Kate & Leopold        0       2001      \N
# 1                                  Kate & Leopold        0       2001      \N
# 2       El Tango del Viudo y Su Espejo Deformante        0       2020      \N
# 3                      The Other Side of the Wind        0       2018      \N
# 4                               The Naked Monster        0       2005      \N
# ...                                           ...      ...        ...     ...
# 101462                  My Girlfriend is a Wizard        0       2019      \N
# 101463                                   O Ensaio        0       2019      \N
# 101464                                  Safeguard        0       2020      \N
# 101465                                   Akelarre        0       2020      \N
# 101466               Hong xing zhao yao Zhong guo        0       2019      \N
#
#        runtimeMinutes                     genres            directors  \
# 0                 118     Comedy,Fantasy,Romance            nm0003506
# 1                 118     Comedy,Fantasy,Romance            nm0003506
# 2                  70                      Drama  nm0749914,nm0765384
# 3                 122                      Drama            nm0000080
# 4                 100       Comedy,Horror,Sci-Fi  nm0078540,nm0628399
# ...               ...                        ...                  ...
# 101462             97       Comedy,Drama,Fantasy            nm8063415
# 101463             51                      Drama            nm5412267
# 101464             90  Action,Adventure,Thriller            nm7308376
# 101465             92              Drama,History            nm1893148
# 101466             \N      Adventure,History,War            nm0910951
#
#                               writers  ordering  \
# 0                 nm0737216,nm0003506        35
# 1                 nm0737216,nm0003506        37
# 2                 nm0749914,nm1146177         5
# 3                 nm0000080,nm0462648         3
# 4                           nm0628399         1
# ...                               ...       ...
# 101462                      nm2507310         3
# 101463  nm5412267,nm6743460,nm3245789         5
# 101464                      nm7308376         6
# 101465            nm1893148,nm3471432        18
# 101466                             \N         3
#
#                                                     title region language  \
# 0                                        Kate and Leopold     US       \N
# 1                                          Kate & Leopold     US       \N
# 2       The Tango of the Widower and Its Distorting Mi...     US       \N
# 3                              The Other Side of the Wind     US       \N
# 4                           Attack of the B-Movie Monster     US       \N
# ...                                                   ...    ...      ...
# 101462                               The Last White Witch     US       \N
# 101463                                      The Rehearsal     US       \N
# 101464                                          Safeguard     US       \N
# 101465                                              Coven     US       \N
# 101466                                The Secret of China     US       \N
#
#               types            attributes isOriginalTitle  averageRating  \
# 0                \N  alternative spelling               0            6.4
# 1       imdbDisplay                    \N               0            6.4
# 2       imdbDisplay                    \N               0            6.4
# 3       imdbDisplay                    \N               0            6.7
# 4           working                    \N               0            5.2
# ...             ...                   ...             ...            ...
# 101462  imdbDisplay                    \N               0            6.9
# 101463  imdbDisplay                    \N               0            6.7
# 101464  imdbDisplay                    \N               0            3.6
# 101465  imdbDisplay                    \N               0            6.4
# 101466  imdbDisplay                    \N               0            3.8
#
#         numVotes
# 0          83822
# 1          83822
# 2            161
# 3           7234
# 4            320
# ...          ...
# 101462         8
# 101463         6
# 101464       233
# 101465      4659
# 101466        14
#
# [101467 rows x 20 columns]

# %%
df8 = pd.read_csv('data-5.tsv', sep ='\t')

# %%
df9 = pd.merge(df7, df8, on='tconst')

# %%
df9.head()
# Out:
#       tconst titleType    primaryTitle   originalTitle  isAdult  startYear  \
# 0  tt0035423     movie  Kate & Leopold  Kate & Leopold        0       2001
# 1  tt0035423     movie  Kate & Leopold  Kate & Leopold        0       2001
# 2  tt0035423     movie  Kate & Leopold  Kate & Leopold        0       2001
# 3  tt0035423     movie  Kate & Leopold  Kate & Leopold        0       2001
# 4  tt0035423     movie  Kate & Leopold  Kate & Leopold        0       2001
#
#   endYear runtimeMinutes                  genres  directors  ... types  \
# 0      \N            118  Comedy,Fantasy,Romance  nm0003506  ...    \N
# 1      \N            118  Comedy,Fantasy,Romance  nm0003506  ...    \N
# 2      \N            118  Comedy,Fantasy,Romance  nm0003506  ...    \N
# 3      \N            118  Comedy,Fantasy,Romance  nm0003506  ...    \N
# 4      \N            118  Comedy,Fantasy,Romance  nm0003506  ...    \N
#
#              attributes isOriginalTitle averageRating numVotes ordering_y  \
# 0  alternative spelling               0           6.4    83822         10
# 1  alternative spelling               0           6.4    83822          1
# 2  alternative spelling               0           6.4    83822          2
# 3  alternative spelling               0           6.4    83822          3
# 4  alternative spelling               0           6.4    83822          4
#
#       nconst category  job         characters
# 0  nm0107463   editor   \N                 \N
# 1  nm0000212  actress   \N     ["Kate McKay"]
# 2  nm0413168    actor   \N        ["Leopold"]
# 3  nm0000630    actor   \N  ["Stuart Besser"]
# 4  nm0005227    actor   \N  ["Charlie McKay"]
#
# [5 rows x 25 columns]

# %%
df9.dtypes
# Out:
# tconst              object
# titleType           object
# primaryTitle        object
# originalTitle       object
# isAdult              int64
# startYear            int64
# endYear             object
# runtimeMinutes      object
# genres              object
# directors           object
# writers             object
# ordering_x           int64
# title               object
# region              object
# language            object
# types               object
# attributes          object
# isOriginalTitle     object
# averageRating      float64
# numVotes             int64
# ordering_y           int64
# nconst              object
# category            object
# job                 object
# characters          object
# dtype: object

# %%
df10 = pd.read_csv('data-6.tsv', sep ='\t')

# %%
df10.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0031983,tt0053137,tt0072308,tt0050419
# 1  tt0117057,tt0037382,tt0071877,tt0038355
# 2  tt0049189,tt0057345,tt0056404,tt0054452
# 3  tt0077975,tt0078723,tt0080455,tt0072562
# 4  tt0050986,tt0060827,tt0083922,tt0050976

# %%
df10.shape
# Out:
# (11654331, 6)

# %%
df11 = pd.merge(df9, df10, on='nconst')

# %%
df11.shape
# Out:
# (900195, 30)

# %%
df11
# Out:
#            tconst titleType            primaryTitle  \
# 0       tt0035423     movie          Kate & Leopold
# 1       tt0035423     movie          Kate & Leopold
# 2       tt0309698     movie                Identity
# 3       tt0309698     movie                Identity
# 4       tt0319262     movie  The Day After Tomorrow
# ...           ...       ...                     ...
# 900190  tt9916362     movie                   Coven
# 900191  tt9916428     movie     The Secret of China
# 900192  tt9916428     movie     The Secret of China
# 900193  tt9916428     movie     The Secret of China
# 900194  tt9916428     movie     The Secret of China
#
#                        originalTitle  isAdult  startYear endYear  \
# 0                     Kate & Leopold        0       2001      \N
# 1                     Kate & Leopold        0       2001      \N
# 2                           Identity        0       2003      \N
# 3                           Identity        0       2003      \N
# 4             The Day After Tomorrow        0       2004      \N
# ...                              ...      ...        ...     ...
# 900190                      Akelarre        0       2020      \N
# 900191  Hong xing zhao yao Zhong guo        0       2019      \N
# 900192  Hong xing zhao yao Zhong guo        0       2019      \N
# 900193  Hong xing zhao yao Zhong guo        0       2019      \N
# 900194  Hong xing zhao yao Zhong guo        0       2019      \N
#
#        runtimeMinutes                   genres  directors  ... ordering_y  \
# 0                 118   Comedy,Fantasy,Romance  nm0003506  ...         10
# 1                 118   Comedy,Fantasy,Romance  nm0003506  ...         10
# 2                  90         Mystery,Thriller  nm0003506  ...         10
# 3                  90         Mystery,Thriller  nm0003506  ...         10
# 4                 124  Action,Adventure,Sci-Fi  nm0000386  ...         10
# ...               ...                      ...        ...  ...        ...
# 900190             92            Drama,History  nm1893148  ...          6
# 900191             \N    Adventure,History,War  nm0910951  ...          2
# 900192             \N    Adventure,History,War  nm0910951  ...          3
# 900193             \N    Adventure,History,War  nm0910951  ...          5
# 900194             \N    Adventure,History,War  nm0910951  ...          6
#
#            nconst  category            job  \
# 0       nm0107463    editor             \N
# 1       nm0107463    editor             \N
# 2       nm0107463    editor             \N
# 3       nm0107463    editor             \N
# 4       nm0107463    editor             \N
# ...           ...       ...            ...
# 900190  nm3471432    writer  screenplay by
# 900191  nm9445072     actor             \N
# 900192  nm8594703     actor             \N
# 900193  nm0910951  director             \N
# 900194  nm8680851     actor             \N
#
#                                         characters     primaryName birthYear  \
# 0                                               \N   David Brenner      1962
# 1                                               \N   David Brenner      1962
# 2                                               \N   David Brenner      1962
# 3                                               \N   David Brenner      1962
# 4                                               \N   David Brenner      1962
# ...                                            ...             ...       ...
# 900190                                          \N  Katell Guillou        \N
# 900191                             ["Mao Ze Dong"]   Wang Peng Kai        \N
# 900192                               ["Dr. Hatem"]  Valery Gadreau        \N
# 900193                                          \N     Jixing Wang        \N
# 900194  ["Powell Editor-in-chief of US newspaper"]  Vincent Matile      1973
#
#        deathYear            primaryProfession  \
# 0           2022  editor,editorial_department
# 1           2022  editor,editorial_department
# 2           2022  editor,editorial_department
# 3           2022  editor,editorial_department
# 4           2022  editor,editorial_department
# ...          ...                          ...
# 900190        \N              writer,director
# 900191        \N                        actor
# 900192        \N                        actor
# 900193        \N              director,writer
# 900194        \N               actor,producer
#
#                                   knownForTitles
# 0        tt1190080,tt0319262,tt0116629,tt0096969
# 1        tt1190080,tt0319262,tt0116629,tt0096969
# 2        tt1190080,tt0319262,tt0116629,tt0096969
# 3        tt1190080,tt0319262,tt0116629,tt0096969
# 4        tt1190080,tt0319262,tt0116629,tt0096969
# ...                                          ...
# 900190  tt9916362,tt12339398,tt2104911,tt8368232
# 900191                       tt7674346,tt9916428
# 900192                                 tt1424310
# 900193  tt1267271,tt0340445,tt0344062,tt13932406
# 900194  tt7294150,tt6628322,tt9378786,tt12630314
#
# [900195 rows x 30 columns]

# %%
df11.to_csv('dirty_df.csv', index=False)

# %%
df12 = pd.read_csv('dirty_df.csv')

# %%
df12.columns
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres', 'directors',
#        'writers', 'ordering_x', 'title', 'region', 'language', 'types',
#        'attributes', 'isOriginalTitle', 'averageRating', 'numVotes',
#        'ordering_y', 'nconst', 'category', 'job', 'characters', 'primaryName',
#        'birthYear', 'deathYear', 'primaryProfession', 'knownForTitles'],
#       dtype='object')

# %%
df12.primaryName.unique()
# Out:
# array(['David Brenner', 'Meg Ryan', 'Hugh Jackman', ..., 'Valery Gadreau',
#        'Jixing Wang', 'Vincent Matile'], dtype=object)
